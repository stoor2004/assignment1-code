# %%
import nltk

# %%
# nltk download only necessary if you haven't done it already, for previous labs
# nltk.download()

# %%
# import texts used with the NLTK book 
from nltk.book import *

# %%
# import a couple other things we'll need
import numpy
import matplotlib

# %%
# change the path to where your data is
corpus1 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/cooking1.txt"

# %%
# change the path to where your data is
corpus2 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/cooking2.txt"

# %%
# change the path to where your data is
corpus3 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/cooking3.txt"

# %%
from nltk.tokenize import word_tokenize
corpus1Tokens=nltk.word_tokenize(corpus1File)

# %%
corpus1File = open(corpus1).read()

# %%
# you can print it, to see that you have a blob of text from the file
corpus1File
# Out:
# 'In theory, I love to cook. I’ve been reminding myself of this lately, repeating it almost like a mantra, humming the percussive, iambic rhythm of the phrase while I clatter around in the cabinets in search of whatever skillet is inevitably at the very bottom of a teetering stack of pans, or ram the blade of a knife through the stalks of yet another head of celery, or fling a handful of salt resentfully at a wholly blameless chicken. In theory, I love to cook.To cook, as a home cook, isn’t just to cook—it’s to plan, to shop, to store, to prep, to combine, to heat, to serve. If I don’t love all those things, all the time, I can at least reliably expect a jolt of pleasure from one or two: the bland labor of chopping onion is paid for, more or less, by the rich smell of the stew as it simmers. But what I love most about cooking (in theory) is that it’s a puzzle to be solved. In its best form, cooking is a practice measured not in individual dishes but in days and even weeks—a strategic 
# ...

# %%
# you can find the length of this blob
len(corpus1Tokens)
# Out:
# 1800

# %%
corpus1Tokens
# Out:
# ['https',
#  ':',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  'This',
#  'article',
#  'is',
#  'part',
#  'of',
#  'our',
#  'latest',
#  'Learning',
#  'special',
#  'report',
#  '.',
#  'We',
#  '’',
#  're',
#  'focusing',
#  'on',
#  'Generation',
#  'Z',
#  ',',
#  'which',
#  'is',
#  'facing',
#  'challenges',
#  'from',
#  'changing',
#  'curriculums',
#  'and',
#  'new',
#  'technology',
#  'to',
#  'financial',
#  'aid',
#  'gaps',
#  'and',
#  'homelessness',
#  '.',
#  'MANCHESTER',
#  ',',
#  'N.H.',
#  '—',
#  'Cruising',
#  'to',
#  'class',
#  'in',
#  'her',
#  'driverless',
#  'car',
#  ',',
#  'a',
#  'student',
#  'crams',
#  'from',
#  'notes',
#  'projected',
#  'on',
#  'the',
#  'inside',
#  'of',
#  'the',
#  'windshield',
#  'while',
#  'she',
#  'gestures',
#  'with',
#  'her',
#  'hands',
#  'to',
#  'shape',
#  'a',
#  '3-D',
#  'holographic',
#  'model',
#  'of',
#  'her',
#  'architecture',
#  'project',
#  '.',
# ...

# %%
# types of words in corpus1Tokens
set(corpus1Tokens)
# Out:
# {'$',
#  '&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  '102',
#  '15-foot',
#  '18',
#  '18-',
#  '19th-century',
#  '200',
#  '21st',
#  '24-year-olds',
#  '3-D',
#  '30',
#  '301',
#  '360-degree',
#  '425',
#  '47',
#  '525',
#  '738,428',
#  '94',
#  ':',
#  ';',
#  '?',
#  'A',
#  'A.I',
#  'A.S.U',
#  'Academic',
#  'Alliance',
#  'America',
#  'American',
#  'And',
#  'Ann',
#  'Another',
#  'Arizona',
#  'At',
#  'Barnes',
#  'Biology',
#  'Boise',
#  'Business',
#  'But',
#  'Center',
#  'Century',
#  'China',
#  'Chinese',
#  'ColLABorative',
#  'College',
#  'Credential',
#  'Cruising',
#  'DeMillo',
#  'Design',
#  'Donna',
#  'Dr.',
#  'EdPlus',
#  'Education',
#  'Engine',
#  'Engineering',
#  'Entangled',
#  'Even',
#  'Everybody',
#  'Future',
#  'Generation',
#  'Georgia',
#  'Gordon',
#  'HAIL',
#  'Hampshire',
#  'Harvesting',
#  'Hechinger',
#  'Herman',
#  'Hey',
#  'However',
#  'Hudson',
# ...

# %%
len(set(corpus1Tokens))
# Out:
# 770

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus1Tokens))
# Out:
# ['$',
#  '&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  '102',
#  '15-foot',
#  '18',
#  '18-',
#  '19th-century',
#  '200',
#  '21st',
#  '24-year-olds',
#  '3-D',
#  '30',
#  '301',
#  '360-degree',
#  '425',
#  '47',
#  '525',
#  '738,428',
#  '94',
#  ':',
#  ';',
#  '?',
#  'A',
#  'A.I',
#  'A.S.U',
#  'Academic',
#  'Alliance',
#  'America',
#  'American',
#  'And',
#  'Ann',
#  'Another',
#  'Arizona',
#  'At',
#  'Barnes',
#  'Biology',
#  'Boise',
#  'Business',
#  'But',
#  'Center',
#  'Century',
#  'China',
#  'Chinese',
#  'ColLABorative',
#  'College',
#  'Credential',
#  'Cruising',
#  'DeMillo',
#  'Design',
#  'Donna',
#  'Dr.',
#  'EdPlus',
#  'Education',
#  'Engine',
#  'Engineering',
#  'Entangled',
#  'Even',
#  'Everybody',
#  'Future',
#  'Generation',
#  'Georgia',
#  'Gordon',
#  'HAIL',
#  'Hampshire',
#  'Harvesting',
#  'Hechinger',
#  'Herman',
#  'Hey',
#  'However',
#  'Hudson',
# ...

# %%
# sorted list of all types in corpus1Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus1Tokens))
# Out:
# ['$',
#  '&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  '102',
#  '15-foot',
#  '18',
#  '18-',
#  '19th-century',
#  '200',
#  '21st',
#  '24-year-olds',
#  '3-d',
#  '30',
#  '301',
#  '360-degree',
#  '425',
#  '47',
#  '525',
#  '738,428',
#  '94',
#  ':',
#  ';',
#  '?',
#  'a',
#  'a.i',
#  'a.s.u',
#  'about',
#  'academic',
#  'access',
#  'according',
#  'accumulated',
#  'achievement',
#  'acquire',
#  'acronyms',
#  'actively',
#  'actually',
#  'added',
#  'advances',
#  'advisers',
#  'advising',
#  'against',
#  'aid',
#  'alert',
#  'all',
#  'alliance',
#  'almost',
#  'alongside',
#  'already',
#  'also',
#  'ambitious',
#  'america',
#  'american',
#  'among',
#  'an',
#  'analysis',
#  'and',
#  'ann',
#  'another',
#  'answered',
#  'answers',
#  'appears',
#  'application',
#  'apprenticeships',
#  'archaeological',
#  'architecture',
#  'are',
#  'arizona',
#  'arm',
#  'article',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus1Tokens)
# Out:
# 0.42777777777777776

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus1Freq = nltk.FreqDist(corpus1Tokens)

# %%
fdist1 = FreqDist(corpus1Tokens)

# %%
fdist1.most_common(10)
# Out:
# [(',', 91),
#  ('.', 69),
#  ('the', 54),
#  ('to', 48),
#  ('of', 43),
#  ('and', 36),
#  ('in', 35),
#  ('a', 34),
#  ('with', 22),
#  ('for', 22)]

# %%
fdist1.hapaxes()
# Out:
# ['https',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  'article',
#  'part',
#  'our',
#  'latest',
#  'Learning',
#  'special',
#  'report',
#  'focusing',
#  'facing',
#  'changing',
#  'curriculums',
#  'aid',
#  'gaps',
#  'homelessness',
#  'MANCHESTER',
#  'N.H.',
#  'Cruising',
#  'class',
#  'driverless',
#  'car',
#  'crams',
#  'notes',
#  'windshield',
#  'while',
#  'hands',
#  '3-D',
#  'holographic',
#  'architecture',
#  'looks',
#  'science',
#  'fiction',
#  'impression',
#  'reinforced',
#  'demonstrated',
#  'ultramodern',
#  'space',
#  'overstuffed',
#  'pillows',
#  'seats',
#  'scenario',
#  'development',
#  'setting',
#  'Sandbox',
#  'ColLABorative',
#  'arm',
#  'fifth',
#  'floor',
#  'downtown',
#  'building',
#  'panoramic',
#  'views',
#  'sprawling',
#  'red',
#  'brick',
#  'date',
#  'city',
#  '19th-century',
#  'industrial',
#  'heyday',
#  'small',
#  'growing',
#  'number',
#  'experts',
#  'using',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences1 = sent_tokenize(corpus1File)

# %%
sentences1
# Out:
# ['In theory, I love to cook.',
#  'I’ve been reminding myself of this lately, repeating it almost like a mantra, humming the percussive, iambic rhythm of the phrase while I clatter around in the cabinets in search of whatever skillet is inevitably at the very bottom of a teetering stack of pans, or ram the blade of a knife through the stalks of yet another head of celery, or fling a handful of salt resentfully at a wholly blameless chicken.',
#  'In theory, I love to cook.To cook, as a home cook, isn’t just to cook—it’s to plan, to shop, to store, to prep, to combine, to heat, to serve.',
#  'If I don’t love all those things, all the time, I can at least reliably expect a jolt of pleasure from one or two: the bland labor of chopping onion is paid for, more or less, by the rich smell of the stew as it simmers.',
#  'But what I love most about cooking (in theory) is that it’s a puzzle to be solved.',
# ...

# %%
longest_sentence1 = max(sentences1)
longest_sentence1_tokenized = nltk.word_tokenize(longest_sentence1)
num_words1 = len(longest_sentence1_tokenized)

num_words1
# Out:
# 45

# %%
longest_sentence1
# Out:
# '“Then they really work, and make you feel noble and brave at the same time.”From the vantage point of abundance, this sentiment is inspiring; in an era of need and shortage, it’s timeless and practical.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence1)
print("\nNumber of Words:", num_words1)
# Out:
# Longest Sentence:
# “Then they really work, and make you feel noble and brave at the same time.”From the vantage point of abundance, this sentiment is inspiring; in an era of need and shortage, it’s timeless and practical.
#
# Number of Words: 45

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence1)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence1_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# “ then they realli work , and make you feel nobl and brave at the same time. ” from the vantag point of abund , thi sentiment is inspir ; in an era of need and shortag , it ’ s timeless and practic .

# %%
corpus2File = open(corpus2).read()

# %%
from nltk.tokenize import word_tokenize
corpus2Tokens=nltk.word_tokenize(corpus2File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus2File
# Out:
# 'Just two generations ago, preparing meals was as much a part of life as eating. Now we’ve given up what is perhaps our best excuse to get together and spend time with the people we love–mealtime–and someone else stands at the stove. We’re either watching cooks on TV like we would a spectator sport or grabbing grub, bagged, and eating it alone and on the go.\nThe fetishizing of food is everywhere. There are cutthroat competitions and celebrity chefs with TV shows, and both social and mainstream media are stuffed with an endless blur of blogs, demos and crowdsourced reviews. So why in Julia’s name do so many Americans still eat tons of hyper processed food, the stuff that is correctly called junk and should really carry warning labels? It’s not because fresh ingredients are hard to come by. Supermarkets offer more variety than ever, and there are over four times as many farmers’ markets in the U.S. as there were 20 years ago. Nor is it for lack of available information. There are plen
# ...

# %%
# you can find the length of this blob
len(corpus2Tokens)
# Out:
# 2715

# %%
# types of words in corpus2Token
set(corpus2Tokens)
# Out:
# {'$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '1',
#  '1-in',
#  '10',
#  '13',
#  '14',
#  '150',
#  '16',
#  '1950s',
#  '2',
#  '20',
#  '200',
#  '24/7',
#  '25',
#  '30',
#  '37,000',
#  '39',
#  '40s',
#  '44,000',
#  '52',
#  '59',
#  '65',
#  '7',
#  '70',
#  '79',
#  ':',
#  ';',
#  '?',
#  'A',
#  'According',
#  'Agriculture',
#  'Although',
#  'American',
#  'Americans',
#  'An',
#  'And',
#  'Annual',
#  'Are',
#  'Aren',
#  'Ask',
#  'Awry',
#  'Back',
#  'Because',
#  'Besides',
#  'Beware',
#  'But',
#  'Buy',
#  'Centers',
#  'Chinese',
#  'City',
#  'Considering',
#  'Control',
#  'Cook',
#  'Cooking',
#  'De',
#  'Department',
#  'Depending',
#  'Diet',
#  'Dinner',
#  'Disease',
#  'Do',
#  'Does',
#  'Eggs',
#  'Everything',
#  'Fast',
#  'For',
#  'Frozen',
#  'Get',
#  'Giada',
#  'Gone',
#  'Grandma',
#  'Growing',
#  'Harris',
#  'Health',
#  'Himalayan',
#  'How',
#  'I',
#  'If',
#  'In',
#  'Instagram',
#  'Instead',
#  'Isn',
#  'It',
#  'Julia',
# ...

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus2Tokens))
# Out:
# ['$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '1',
#  '1-in',
#  '10',
#  '13',
#  '14',
#  '150',
#  '16',
#  '1950s',
#  '2',
#  '20',
#  '200',
#  '24/7',
#  '25',
#  '30',
#  '37,000',
#  '39',
#  '40s',
#  '44,000',
#  '52',
#  '59',
#  '65',
#  '7',
#  '70',
#  '79',
#  ':',
#  ';',
#  '?',
#  'A',
#  'According',
#  'Agriculture',
#  'Although',
#  'American',
#  'Americans',
#  'An',
#  'And',
#  'Annual',
#  'Are',
#  'Aren',
#  'Ask',
#  'Awry',
#  'Back',
#  'Because',
#  'Besides',
#  'Beware',
#  'But',
#  'Buy',
#  'Centers',
#  'Chinese',
#  'City',
#  'Considering',
#  'Control',
#  'Cook',
#  'Cooking',
#  'De',
#  'Department',
#  'Depending',
#  'Diet',
#  'Dinner',
#  'Disease',
#  'Do',
#  'Does',
#  'Eggs',
#  'Everything',
#  'Fast',
#  'For',
#  'Frozen',
#  'Get',
#  'Giada',
#  'Gone',
#  'Grandma',
#  'Growing',
#  'Harris',
#  'Health',
#  'Himalayan',
#  'How',
#  'I',
#  'If',
#  'In',
#  'Instagram',
#  'Instead',
#  'Isn',
#  'It',
#  'Julia',
# ...

# %%
# sorted list of all types in corpus2Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus2Tokens))
# Out:
# ['$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '1',
#  '1-in',
#  '10',
#  '13',
#  '14',
#  '150',
#  '16',
#  '1950s',
#  '2',
#  '20',
#  '200',
#  '24/7',
#  '25',
#  '30',
#  '37,000',
#  '39',
#  '40s',
#  '44,000',
#  '52',
#  '59',
#  '65',
#  '7',
#  '70',
#  '79',
#  ':',
#  ';',
#  '?',
#  'a',
#  'about',
#  'abundance',
#  'accept',
#  'access',
#  'accessible–and',
#  'according',
#  'account',
#  'accounts',
#  'accurate',
#  'activities',
#  'activity',
#  'actually',
#  'added',
#  'adjust',
#  'advance',
#  'advanced',
#  'advice',
#  'afford',
#  'affordable',
#  'after',
#  'against',
#  'ages',
#  'ago',
#  'agriculture',
#  'ahead',
#  'aisle',
#  'aisles',
#  'alcohol',
#  'all',
#  'allowed',
#  'allows',
#  'almost',
#  'alone',
#  'also',
#  'although',
#  'ambitions',
#  'ambitious',
#  'american',
#  'americans',
#  'amount',
#  'an',
#  'and',
#  'annual',
#  'annually',
#  'any',
#  'anyone',
#  'anything',
#  'appear',
#  'appetizing',
#  'are',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus2Tokens)
# Out:
# 0.3558011049723757

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus2Freq = nltk.FreqDist(corpus2Tokens)

# %%
fdist2 = FreqDist(corpus2Tokens)

# %%
fdist2.most_common(10)
# Out:
# [(',', 144),
#  ('.', 106),
#  ('the', 101),
#  ('and', 76),
#  ('to', 73),
#  ('’', 65),
#  ('of', 56),
#  ('you', 41),
#  ('a', 40),
#  ('that', 34)]

# %%
fdist2.hapaxes()
# Out:
# ['generations',
#  'Now',
#  'given',
#  'perhaps',
#  'excuse',
#  'together',
#  'spend',
#  'love–mealtime–and',
#  'stands',
#  'either',
#  'spectator',
#  'sport',
#  'grabbing',
#  'grub',
#  'bagged',
#  'fetishizing',
#  'everywhere',
#  'cutthroat',
#  'competitions',
#  'mainstream',
#  'media',
#  'stuffed',
#  'endless',
#  'blur',
#  'demos',
#  'crowdsourced',
#  'reviews',
#  'why',
#  'Julia',
#  'name',
#  'hyper',
#  'stuff',
#  'correctly',
#  'really',
#  'carry',
#  'warning',
#  'labels',
#  'come',
#  'Supermarkets',
#  'offer',
#  'variety',
#  'four',
#  'farmers',
#  'markets',
#  'years',
#  'Nor',
#  'lack',
#  'how-to',
#  'videos',
#  'classes',
#  'computer',
#  'smartphone',
#  'television',
#  'overwhelming',
#  'yet',
#  'aren',
#  'three',
#  'squares',
#  'behave',
#  'increasingly',
#  'world',
#  'probably',
#  'outside',
#  'Nearly',
#  'two-thirds',
#  'grab',
#  'fast',
#  'once',
#  '25',
#  'snacks',
#  'out',
#  'sit',
#  'down–or',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences2 = sent_tokenize(corpus2File)

# %%
sentences2
# Out:
# ['Just two generations ago, preparing meals was as much a part of life as eating.',
#  'Now we’ve given up what is perhaps our best excuse to get together and spend time with the people we love–mealtime–and someone else stands at the stove.',
#  'We’re either watching cooks on TV like we would a spectator sport or grabbing grub, bagged, and eating it alone and on the go.',
#  'The fetishizing of food is everywhere.',
#  'There are cutthroat competitions and celebrity chefs with TV shows, and both social and mainstream media are stuffed with an endless blur of blogs, demos and crowdsourced reviews.',
#  'So why in Julia’s name do so many Americans still eat tons of hyper processed food, the stuff that is correctly called junk and should really carry warning labels?',
#  'It’s not because fresh ingredients are hard to come by.',
#  'Supermarkets offer more variety than ever, and there are over four times as many farmers’ markets in the U.S. as there were 20 years ago.',
# ...

# %%
longest_sentence2 = max(sentences2)
longest_sentence2_tokenized = nltk.word_tokenize(longest_sentence2)
num_words2 = len(longest_sentence2_tokenized)

num_words2
# Out:
# 12

# %%
longest_sentence2
# Out:
# 'cubes”–that’s 10 minutes’ work right there.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence2)
print("\nNumber of Words:", num_words2)
# Out:
# Longest Sentence:
# cubes”–that’s 10 minutes’ work right there.
#
# Number of Words: 12

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence2)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence2_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# cube ” –that ’ s 10 minut ’ work right there .

# %%
corpus3File = open(corpus3).read()

# %%
#from nltk.tokenize import word_tokenize
corpus3Tokens=nltk.word_tokenize(corpus3File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus3File
# Out:
# 'The Emotional Benefits of Cooking\nWhether you\'re drowning your sorrows in a pint of Blue Bell ice cream or eating your feelings at the Waffle House, there\'s no doubt that eating is therapeutic. As anyone who has found themselves beating eggs, whipping cream, and pounding out biscuit dough can attest, cooking can be pretty therapeutic, as well.\nWhile any Southern grandma would probably scoff at the need for a study on the idea of cooking as therapy—because, of course, retreating to the kitchen to whip up fried chicken, collards, and cornbread is good for the soul—one study found that baking classes boosted confidence and increased concentration.1 Another study revealed that a little creativity and creation in the kitchen can make people happier. That study, published in the Journal of Positive Psychology, suggests that people who frequently take on small, creative projects like baking or cooking report feeling more relaxed and happier in their everyday lives.2 The researchers fol
# ...

# %%
# you can find the length of this blob
len(corpus3Tokens)
# Out:
# 849

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
# types of words in corpus3Tokens
set(corpus3Tokens)
# Out:
# {"'",
#  "''",
#  "'helped",
#  "'m",
#  "'re",
#  "'s",
#  '(',
#  ')',
#  ',',
#  '.',
#  '2005',
#  '2012',
#  '658',
#  'ADHD',
#  'According',
#  'And',
#  'Another',
#  'As',
#  'AviShai',
#  'BBC',
#  'Bake',
#  'Baking',
#  'Being',
#  'Bell',
#  'Benefits',
#  'Blue',
#  'British',
#  'Connect',
#  'Conner',
#  'Cooking',
#  'Culinary',
#  'Emotional',
#  'Focus',
#  'Great',
#  'Guardian',
#  'Helps',
#  'House',
#  'How',
#  'Huffington',
#  'I',
#  'Improves',
#  'In',
#  'It',
#  'John',
#  'Journal',
#  'Journalreported',
#  'Meditation',
#  'Michal',
#  'Munchies',
#  'Namely',
#  'New',
#  'Off',
#  'Otago',
#  'Others',
#  'Positive',
#  'Post',
#  'Psychologists',
#  'Psychology',
#  'Southern',
#  'Street',
#  'Tamlin',
#  'Telegraph',
#  'That',
#  'The',
#  'There',
#  'These',
#  'Through',
#  'University',
#  'WSJ',
#  'Waffle',
#  'Wall',
#  'Wellbeing',
#  'Whaite',
#  'When',
#  'Whether',
#  'While',
#  'You',
#  'Zealand',
#  '``',
#  'a',
#  'about',
# ...

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus3Tokens))
# Out:
# ["'",
#  "''",
#  "'helped",
#  "'m",
#  "'re",
#  "'s",
#  '(',
#  ')',
#  ',',
#  '.',
#  '2005',
#  '2012',
#  '658',
#  'ADHD',
#  'According',
#  'And',
#  'Another',
#  'As',
#  'AviShai',
#  'BBC',
#  'Bake',
#  'Baking',
#  'Being',
#  'Bell',
#  'Benefits',
#  'Blue',
#  'British',
#  'Connect',
#  'Conner',
#  'Cooking',
#  'Culinary',
#  'Emotional',
#  'Focus',
#  'Great',
#  'Guardian',
#  'Helps',
#  'House',
#  'How',
#  'Huffington',
#  'I',
#  'Improves',
#  'In',
#  'It',
#  'John',
#  'Journal',
#  'Journalreported',
#  'Meditation',
#  'Michal',
#  'Munchies',
#  'Namely',
#  'New',
#  'Off',
#  'Otago',
#  'Others',
#  'Positive',
#  'Post',
#  'Psychologists',
#  'Psychology',
#  'Southern',
#  'Street',
#  'Tamlin',
#  'Telegraph',
#  'That',
#  'The',
#  'There',
#  'These',
#  'Through',
#  'University',
#  'WSJ',
#  'Waffle',
#  'Wall',
#  'Wellbeing',
#  'Whaite',
#  'When',
#  'Whether',
#  'While',
#  'You',
#  'Zealand',
#  '``',
#  'a',
#  'about',
# ...

# %%
# sorted list of all types in corpus3Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus3Tokens))
# Out:
# ["'",
#  "''",
#  "'helped",
#  "'m",
#  "'re",
#  "'s",
#  '(',
#  ')',
#  ',',
#  '.',
#  '2005',
#  '2012',
#  '658',
#  '``',
#  'a',
#  'about',
#  'according',
#  'act',
#  'activation',
#  'activities',
#  'added',
#  'addiction',
#  'adhd',
#  'adjusting',
#  'all',
#  'alleviate',
#  'already',
#  'also',
#  'altruism',
#  'am',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'anxiety',
#  'any',
#  'anyone',
#  'are',
#  'arts',
#  'as',
#  'associated',
#  'at',
#  'attest',
#  'author',
#  'avishai',
#  'bake',
#  'baker',
#  'baking',
#  'bbc',
#  'be',
#  'beating',
#  'because',
#  'behavior',
#  'behavioral',
#  'being',
#  'believe',
#  'bell',
#  'benefit',
#  'benefits',
#  'better',
#  'biscuit',
#  'bit',
#  'blue',
#  'boon',
#  'boosted',
#  'british',
#  'build',
#  'but',
#  'butter',
#  'by',
#  'can',
#  'chicken',
#  'classes',
#  'collards',
#  'combination',
#  'comes',
#  'community',
#  'concentration.1',
#  'condition',
#  'confidence',
# ...

# %%
lexical_diversity(corpus3Tokens)
# Out:
# 0.4617196702002356

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus3Freq = nltk.FreqDist(corpus3Tokens)

# %%
fdist3 = FreqDist(corpus3Tokens)

# %%
fdist3.most_common(10)
# Out:
# [(',', 51),
#  ('the', 31),
#  ('and', 25),
#  ('of', 24),
#  ('.', 23),
#  ('a', 19),
#  ('in', 17),
#  ('that', 14),
#  ('cooking', 14),
#  ('to', 14)]

# %%
fdist3.hapaxes()
# Out:
# ['Benefits',
#  'Whether',
#  'drowning',
#  'sorrows',
#  'pint',
#  'Blue',
#  'Bell',
#  'ice',
#  'feelings',
#  'Waffle',
#  'House',
#  'doubt',
#  'As',
#  'anyone',
#  'has',
#  'themselves',
#  'beating',
#  'eggs',
#  'whipping',
#  'pounding',
#  'out',
#  'biscuit',
#  'dough',
#  'attest',
#  'pretty',
#  'Southern',
#  'grandma',
#  'would',
#  'scoff',
#  'idea',
#  'therapy—because',
#  'course',
#  'retreating',
#  'whip',
#  'up',
#  'fried',
#  'chicken',
#  'collards',
#  'cornbread',
#  'soul—one',
#  'boosted',
#  'confidence',
#  'increased',
#  'concentration.1',
#  'Another',
#  'revealed',
#  'creation',
#  'published',
#  'Positive',
#  'Psychology',
#  'suggests',
#  'frequently',
#  'take',
#  'report',
#  'relaxed',
#  'lives.2',
#  'researchers',
#  'followed',
#  '658',
#  'two',
#  'weeks',
#  'group',
#  'enthusiastic',
#  'pursuits',
#  'next',
#  'food',
#  'website',
#  'Munchies',
#  'Improves',
#  'Wellbeing',
#  'Being',
#  'while',
#  'each',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences3 = sent_tokenize(corpus3File)

# %%
sentences3
# Out:
# ["The Emotional Benefits of Cooking\nWhether you're drowning your sorrows in a pint of Blue Bell ice cream or eating your feelings at the Waffle House, there's no doubt that eating is therapeutic.",
#  'As anyone who has found themselves beating eggs, whipping cream, and pounding out biscuit dough can attest, cooking can be pretty therapeutic, as well.',
#  'While any Southern grandma would probably scoff at the need for a study on the idea of cooking as therapy—because, of course, retreating to the kitchen to whip up fried chicken, collards, and cornbread is good for the soul—one study found that baking classes boosted confidence and increased concentration.1 Another study revealed that a little creativity and creation in the kitchen can make people happier.',
# ...

# %%
longest_sentence3 = max(sentences3)
longest_sentence3_tokenized = nltk.word_tokenize(longest_sentence3)
num_words3 = len(longest_sentence3_tokenized)

num_words3
# Out:
# 27

# %%
longest_sentence3
# Out:
# 'While any form of altruism can make people feel happy and connected to others, cooking for others helps people fulfill needs and that is important.'

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence3)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence3_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# while ani form of altruism can make peopl feel happi and connect to other , cook for other help peopl fulfil need and that is import .

# %%
pwd
# Out:
# '/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1'

# %%
# change the path to where your data is
corpus12 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/article1.txt"

# %%
corpus4File = open(corpus12).read()

# %%
from nltk.tokenize import word_tokenize
corpus12Tokens=nltk.word_tokenize(corpus4File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus4File
# Out:
# 'We are living through an incredibly exciting period for prosthetics. A pioneering brain computer interface that will allow veterans to control artificial body parts with their minds was recently announced by researchers in Virginia in the US. Meanwhile, Newcastle University in the UK is developing limbs which “see” objects in front of them and react at speeds more comparable with the real thing.\nProjects like these are steadily helping people with prostheses to move more naturally and easily than ever before. But what few people appreciate is just how far back this field actually goes.\nIf you were thinking a couple of hundred years, or maybe since the medieval era, you wouldn’t even be close. Amputations and prostheses date back to ancient times, and saw advances that were heralded as no less life-changing then as they are today. It’s a fascinating story of gods, gladiators and the limits of human endurance that adds a whole other dimension to understanding this discipline.\nWarfa
# ...

# %%
# you can find the length of this blob
len(corpus12Tokens)
# Out:
# 1023

# %%
corpus12Tokens
# Out:
# ['We',
#  'are',
#  'living',
#  'through',
#  'an',
#  'incredibly',
#  'exciting',
#  'period',
#  'for',
#  'prosthetics',
#  '.',
#  'A',
#  'pioneering',
#  'brain',
#  'computer',
#  'interface',
#  'that',
#  'will',
#  'allow',
#  'veterans',
#  'to',
#  'control',
#  'artificial',
#  'body',
#  'parts',
#  'with',
#  'their',
#  'minds',
#  'was',
#  'recently',
#  'announced',
#  'by',
#  'researchers',
#  'in',
#  'Virginia',
#  'in',
#  'the',
#  'US',
#  '.',
#  'Meanwhile',
#  ',',
#  'Newcastle',
#  'University',
#  'in',
#  'the',
#  'UK',
#  'is',
#  'developing',
#  'limbs',
#  'which',
#  '“',
#  'see',
#  '”',
#  'objects',
#  'in',
#  'front',
#  'of',
#  'them',
#  'and',
#  'react',
#  'at',
#  'speeds',
#  'more',
#  'comparable',
#  'with',
#  'the',
#  'real',
#  'thing',
#  '.',
#  'Projects',
#  'like',
#  'these',
#  'are',
#  'steadily',
#  'helping',
#  'people',
#  'with',
#  'prostheses',
#  'to',
#  'move',
#  'more',
#  'naturally',
#  'and',
# ...

# %%
# types of words in corpus12Tokens
set(corpus12Tokens)
# Out:
# {'(',
#  ')',
#  ',',
#  '.',
#  '16th',
#  '20',
#  '218-201BC',
#  '25',
#  '323-31BC',
#  '499-449BC',
#  '80',
#  ':',
#  'A',
#  'Afghanistan',
#  'After',
#  'Alexandria',
#  'Ambroise',
#  'Amputations',
#  'An',
#  'Ancient',
#  'And',
#  'Another',
#  'Around',
#  'BC',
#  'But',
#  'Capua',
#  'Carthage',
#  'Egypt',
#  'French',
#  'Graeco-Persian',
#  'Greece',
#  'Greek',
#  'Hannibal',
#  'He',
#  'Hegesistratus',
#  'Hellenistic',
#  'Hephaistos',
#  'Herodotus',
#  'Hippocratic',
#  'If',
#  'In',
#  'Iraq',
#  'It',
#  'Italy',
#  'Joints',
#  'Library',
#  'Long',
#  'Luxor',
#  'Marcus',
#  'Meanwhile',
#  'Museion',
#  'Newcastle',
#  'Of',
#  'On',
#  'Paralympics',
#  'Paré',
#  'Persian',
#  'Projects',
#  'Prosthetic',
#  'Punic',
#  'Roman',
#  'Romans',
#  'Rome',
#  'Second',
#  'Sergius',
#  'Silus',
#  'Soldiers',
#  'Spartans',
#  'Surgical',
#  'Surviving',
#  'That',
#  'The',
#  'There',
#  'These',
#  'They',
#  'This',
#  'Tunisia',
#  'UK',
# ...

# %%
len(set(corpus12Tokens))
# Out:
# 523

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus12Tokens))
# Out:
# ['(',
#  ')',
#  ',',
#  '.',
#  '16th',
#  '20',
#  '218-201BC',
#  '25',
#  '323-31BC',
#  '499-449BC',
#  '80',
#  ':',
#  'A',
#  'Afghanistan',
#  'After',
#  'Alexandria',
#  'Ambroise',
#  'Amputations',
#  'An',
#  'Ancient',
#  'And',
#  'Another',
#  'Around',
#  'BC',
#  'But',
#  'Capua',
#  'Carthage',
#  'Egypt',
#  'French',
#  'Graeco-Persian',
#  'Greece',
#  'Greek',
#  'Hannibal',
#  'He',
#  'Hegesistratus',
#  'Hellenistic',
#  'Hephaistos',
#  'Herodotus',
#  'Hippocratic',
#  'If',
#  'In',
#  'Iraq',
#  'It',
#  'Italy',
#  'Joints',
#  'Library',
#  'Long',
#  'Luxor',
#  'Marcus',
#  'Meanwhile',
#  'Museion',
#  'Newcastle',
#  'Of',
#  'On',
#  'Paralympics',
#  'Paré',
#  'Persian',
#  'Projects',
#  'Prosthetic',
#  'Punic',
#  'Roman',
#  'Romans',
#  'Rome',
#  'Second',
#  'Sergius',
#  'Silus',
#  'Soldiers',
#  'Spartans',
#  'Surgical',
#  'Surviving',
#  'That',
#  'The',
#  'There',
#  'These',
#  'They',
#  'This',
#  'Tunisia',
#  'UK',
# ...

# %%
# sorted list of all types in corpus12Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus12Tokens))
# Out:
# ['(',
#  ')',
#  ',',
#  '.',
#  '16th',
#  '20',
#  '218-201bc',
#  '25',
#  '323-31bc',
#  '499-449bc',
#  '80',
#  ':',
#  'a',
#  'able',
#  'about',
#  'account',
#  'achieve',
#  'acquired',
#  'actually',
#  'adds',
#  'advanced',
#  'advances',
#  'afghanistan',
#  'after',
#  'against',
#  'alexandria',
#  'allow',
#  'alternatives',
#  'amazing',
#  'ambroise',
#  'amenable',
#  'amends',
#  'amputated',
#  'amputating',
#  'amputations',
#  'an',
#  'anatomy',
#  'ancient',
#  'and',
#  'announced',
#  'another',
#  'appreciate',
#  'are',
#  'arm',
#  'armour',
#  'arms',
#  'around',
#  'artificial',
#  'artisans',
#  'artists',
#  'as',
#  'association',
#  'at',
#  'athletes',
#  'attests',
#  'available',
#  'back',
#  'barely',
#  'battle',
#  'bc',
#  'be',
#  'bear',
#  'become',
#  'been',
#  'before',
#  'below',
#  'belt',
#  'bending',
#  'benefited',
#  'between',
#  'blade',
#  'bleeding',
#  'blood',
#  'bodies',
#  'body',
#  'brain',
#  'bronze',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus12Tokens)
# Out:
# 0.5112414467253177

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus12Freq = nltk.FreqDist(corpus12Tokens)

# %%
fdist12 = FreqDist(corpus12Tokens)

# %%
fdist12.most_common(10)
# Out:
# [(',', 42),
#  ('the', 41),
#  ('.', 40),
#  ('to', 34),
#  ('and', 24),
#  ('of', 23),
#  ('in', 17),
#  ('that', 14),
#  ('a', 13),
#  ('prostheses', 10)]

# %%
fdist12.hapaxes()
# Out:
# ['living',
#  'through',
#  'exciting',
#  'prosthetics',
#  'A',
#  'pioneering',
#  'brain',
#  'computer',
#  'interface',
#  'will',
#  'allow',
#  'control',
#  'body',
#  'parts',
#  'minds',
#  'recently',
#  'announced',
#  'researchers',
#  'Virginia',
#  'US',
#  'Meanwhile',
#  'Newcastle',
#  'University',
#  'UK',
#  'developing',
#  'limbs',
#  '“',
#  '”',
#  'objects',
#  'front',
#  'react',
#  'speeds',
#  'comparable',
#  'thing',
#  'Projects',
#  'steadily',
#  'move',
#  'naturally',
#  'easily',
#  'ever',
#  'what',
#  'few',
#  'appreciate',
#  'field',
#  'actually',
#  'goes',
#  'If',
#  'thinking',
#  'couple',
#  'hundred',
#  'years',
#  'maybe',
#  'medieval',
#  'wouldn',
#  'close',
#  'Amputations',
#  'date',
#  'saw',
#  'heralded',
#  'no',
#  'life-changing',
#  'fascinating',
#  'story',
#  'gods',
#  'gladiators',
#  'limits',
#  'human',
#  'endurance',
#  'adds',
#  'whole',
#  'other',
#  'dimension',
#  'discipline',
#  'Warfare',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences12 = sent_tokenize(corpus4File)

# %%
sentences12
# Out:
# ['We are living through an incredibly exciting period for prosthetics.',
#  'A pioneering brain computer interface that will allow veterans to control artificial body parts with their minds was recently announced by researchers in Virginia in the US.',
#  'Meanwhile, Newcastle University in the UK is developing limbs which “see” objects in front of them and react at speeds more comparable with the real thing.',
#  'Projects like these are steadily helping people with prostheses to move more naturally and easily than ever before.',
#  'But what few people appreciate is just how far back this field actually goes.',
#  'If you were thinking a couple of hundred years, or maybe since the medieval era, you wouldn’t even be close.',
#  'Amputations and prostheses date back to ancient times, and saw advances that were heralded as no less life-changing then as they are today.',
# ...

# %%
longest_sentence12 = max(sentences12)
longest_sentence12_tokenized = nltk.word_tokenize(longest_sentence12)
num_words12 = len(longest_sentence12_tokenized)

num_words12
# Out:
# 41

# %%
longest_sentence12
# Out:
# 'Yet it seems probable that the technology improved due to the horrors of war – just as today’s advances are partly a response to the unprecedented levels of multiple traumatic injuries that soldiers suffered in Afghanistan and Iraq.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence12)
print("\nNumber of Words:", num_words12)
# Out:
# Longest Sentence:
# Yet it seems probable that the technology improved due to the horrors of war – just as today’s advances are partly a response to the unprecedented levels of multiple traumatic injuries that soldiers suffered in Afghanistan and Iraq.
#
# Number of Words: 41

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence12)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence12_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# yet it seem probabl that the technolog improv due to the horror of war – just as today ’ s advanc are partli a respons to the unpreced level of multipl traumat injuri that soldier suffer in afghanistan and iraq .

# %%
# change the path to where your data is
corpus22 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/article2.txt"

# %%
corpus5File = open(corpus22).read()

# %%
from nltk.tokenize import word_tokenize
corpus22Tokens=nltk.word_tokenize(corpus5File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus5File
# Out:
# 'Known as the Renaissance, the period immediately following the Middle Ages in Europe saw a great revival of interest in the classical learning and values of ancient Greece and Rome. Against a backdrop of political stability and growing prosperity, the development of new technologies–including the printing press, a new system of astronomy and the discovery and exploration of new continents–was accompanied by a flowering of philosophy, literature and especially art. \nThe style of painting, sculpture and decorative arts identified with the Renaissance emerged in Italy in the late 14th century; it reached its zenith in the late 15th and early 16th centuries, in the work of Italian masters such as Leonardo da Vinci, Michelangelo and Raphael. In addition to its expression of classical Greco-Roman traditions, Renaissance art sought to capture the experience of the individual and the beauty and mystery of the natural world.\nOrigins of Renaissance Art \nThe origins of Renaissance art can b
# ...

# %%
# you can find the length of this blob
len(corpus22Tokens)
# Out:
# 1604

# %%
corpus22Tokens
# Out:
# ['Known',
#  'as',
#  'the',
#  'Renaissance',
#  ',',
#  'the',
#  'period',
#  'immediately',
#  'following',
#  'the',
#  'Middle',
#  'Ages',
#  'in',
#  'Europe',
#  'saw',
#  'a',
#  'great',
#  'revival',
#  'of',
#  'interest',
#  'in',
#  'the',
#  'classical',
#  'learning',
#  'and',
#  'values',
#  'of',
#  'ancient',
#  'Greece',
#  'and',
#  'Rome',
#  '.',
#  'Against',
#  'a',
#  'backdrop',
#  'of',
#  'political',
#  'stability',
#  'and',
#  'growing',
#  'prosperity',
#  ',',
#  'the',
#  'development',
#  'of',
#  'new',
#  'technologies–including',
#  'the',
#  'printing',
#  'press',
#  ',',
#  'a',
#  'new',
#  'system',
#  'of',
#  'astronomy',
#  'and',
#  'the',
#  'discovery',
#  'and',
#  'exploration',
#  'of',
#  'new',
#  'continents–was',
#  'accompanied',
#  'by',
#  'a',
#  'flowering',
#  'of',
#  'philosophy',
#  ',',
#  'literature',
#  'and',
#  'especially',
#  'art',
#  '.',
#  'The',
#  'style',
#  'of',
#  'painting',
#  ',',
# ...

# %%
# types of words in corpus22Tokens
set(corpus22Tokens)
# Out:
# {"''",
#  '(',
#  ')',
#  ',',
#  '-1337',
#  '.',
#  '1267',
#  '1280-1400',
#  '1304-1374',
#  '1313-1375',
#  '1377-1446',
#  '1378-1455',
#  '1386-',
#  '13th',
#  '1401',
#  '1401-1428',
#  '1401-1490s',
#  '1426',
#  '1427',
#  '1432',
#  '1434',
#  '1441',
#  '1452-1519',
#  '1466',
#  '1471-1528',
#  '1475-1564',
#  '1477/78-1510',
#  '1485',
#  '1488/90-1576',
#  '1490s',
#  '1490s-1527',
#  '1492',
#  '1494',
#  '1495-98',
#  '1497/98-1543',
#  '1499',
#  '14th',
#  '1500s',
#  '1501-04',
#  '1503-05',
#  '1508-11',
#  '1508-12',
#  '1512',
#  '1527',
#  '1550',
#  '15th',
#  '16th',
#  '16th-century',
#  ':',
#  ';',
#  '?',
#  'Against',
#  'Ages',
#  'Albrecht',
#  'Among',
#  'Architects',
#  'Art',
#  'Assisi',
#  'Athens',
#  'Baptistery',
#  'Boccaccio',
#  'Botticelli',
#  'Bramante',
#  'Brancacci',
#  'Brunelleschi',
#  'Buonarroti',
#  'By',
#  'Carmine',
#  'Cathedral',
#  'Catholic',
#  'Chapel',
#  'Chapel–skillfully',
#  'Charles',
#  'Church',
# ...

# %%
len(set(corpus22Tokens))
# Out:
# 629

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus22Tokens))
# Out:
# ["''",
#  '(',
#  ')',
#  ',',
#  '-1337',
#  '.',
#  '1267',
#  '1280-1400',
#  '1304-1374',
#  '1313-1375',
#  '1377-1446',
#  '1378-1455',
#  '1386-',
#  '13th',
#  '1401',
#  '1401-1428',
#  '1401-1490s',
#  '1426',
#  '1427',
#  '1432',
#  '1434',
#  '1441',
#  '1452-1519',
#  '1466',
#  '1471-1528',
#  '1475-1564',
#  '1477/78-1510',
#  '1485',
#  '1488/90-1576',
#  '1490s',
#  '1490s-1527',
#  '1492',
#  '1494',
#  '1495-98',
#  '1497/98-1543',
#  '1499',
#  '14th',
#  '1500s',
#  '1501-04',
#  '1503-05',
#  '1508-11',
#  '1508-12',
#  '1512',
#  '1527',
#  '1550',
#  '15th',
#  '16th',
#  '16th-century',
#  ':',
#  ';',
#  '?',
#  'Against',
#  'Ages',
#  'Albrecht',
#  'Among',
#  'Architects',
#  'Art',
#  'Assisi',
#  'Athens',
#  'Baptistery',
#  'Boccaccio',
#  'Botticelli',
#  'Bramante',
#  'Brancacci',
#  'Brunelleschi',
#  'Buonarroti',
#  'By',
#  'Carmine',
#  'Cathedral',
#  'Catholic',
#  'Chapel',
#  'Chapel–skillfully',
#  'Charles',
#  'Church',
# ...

# %%
# sorted list of all types in corpus22Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus22Tokens))
# Out:
# ["''",
#  '(',
#  ')',
#  ',',
#  '-1337',
#  '.',
#  '1267',
#  '1280-1400',
#  '1304-1374',
#  '1313-1375',
#  '1377-1446',
#  '1378-1455',
#  '1386-',
#  '13th',
#  '1401',
#  '1401-1428',
#  '1401-1490s',
#  '1426',
#  '1427',
#  '1432',
#  '1434',
#  '1441',
#  '1452-1519',
#  '1466',
#  '1471-1528',
#  '1475-1564',
#  '1477/78-1510',
#  '1485',
#  '1488/90-1576',
#  '1490s',
#  '1490s-1527',
#  '1492',
#  '1494',
#  '1495-98',
#  '1497/98-1543',
#  '1499',
#  '14th',
#  '1500s',
#  '1501-04',
#  '1503-05',
#  '1508-11',
#  '1508-12',
#  '1512',
#  '1527',
#  '1550',
#  '15th',
#  '16th',
#  '16th-century',
#  ':',
#  ';',
#  '?',
#  '``',
#  'a',
#  'ability',
#  'accompanied',
#  'achieved',
#  'achievements',
#  'addition',
#  'admitted',
#  'advances',
#  'after',
#  'again',
#  'against',
#  'age',
#  'ages',
#  'albrecht',
#  'alike–and',
#  'all',
#  'allowed',
#  'altarpiece',
#  'altarpieces',
#  'ambitious',
#  'among',
#  'an',
#  'anatomy',
#  'ancient',
#  'and',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus22Tokens)
# Out:
# 0.39214463840399

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus22Freq = nltk.FreqDist(corpus22Tokens)

# %%
fdist22 = FreqDist(corpus22Tokens)

# %%
fdist22.most_common(10)
# Out:
# [('the', 126),
#  (',', 83),
#  ('of', 75),
#  ('and', 62),
#  ('.', 43),
#  ('(', 30),
#  (')', 30),
#  ('in', 28),
#  ('Renaissance', 27),
#  ('as', 26)]

# %%
fdist22.hapaxes()
# Out:
# ['Known',
#  'immediately',
#  'following',
#  'Middle',
#  'Ages',
#  'revival',
#  'learning',
#  'Against',
#  'backdrop',
#  'political',
#  'stability',
#  'growing',
#  'prosperity',
#  'development',
#  'technologies–including',
#  'printing',
#  'press',
#  'system',
#  'astronomy',
#  'discovery',
#  'exploration',
#  'continents–was',
#  'accompanied',
#  'philosophy',
#  'literature',
#  'especially',
#  'decorative',
#  'identified',
#  'emerged',
#  'reached',
#  'zenith',
#  'Greco-Roman',
#  'capture',
#  'experience',
#  'individual',
#  'mystery',
#  'natural',
#  'world',
#  'Origins',
#  'origins',
#  'During',
#  'so-called',
#  '1280-1400',
#  'scholars',
#  'themselves',
#  'reawakening',
#  'achievements',
#  'culture',
#  'Writers',
#  'Petrarch',
#  '1304-1374',
#  'Giovanni',
#  'Boccaccio',
#  '1313-1375',
#  'looked',
#  'revive',
#  'languages',
#  'those',
#  'cultures',
#  'after',
#  'long',
#  'stagnation',
#  'followed',
#  'fall',
#  'Empire',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences22 = sent_tokenize(corpus5File)

# %%
sentences22
# Out:
# ['Known as the Renaissance, the period immediately following the Middle Ages in Europe saw a great revival of interest in the classical learning and values of ancient Greece and Rome.',
#  'Against a backdrop of political stability and growing prosperity, the development of new technologies–including the printing press, a new system of astronomy and the discovery and exploration of new continents–was accompanied by a flowering of philosophy, literature and especially art.',
#  'The style of painting, sculpture and decorative arts identified with the Renaissance emerged in Italy in the late 14th century; it reached its zenith in the late 15th and early 16th centuries, in the work of Italian masters such as Leonardo da Vinci, Michelangelo and Raphael.',
#  'In addition to its expression of classical Greco-Roman traditions, Renaissance art sought to capture the experience of the individual and the beauty and mystery of the natural world.',
# ...

# %%
longest_sentence22 = max(sentences22)
longest_sentence22_tokenized = nltk.word_tokenize(longest_sentence22)
num_words22 = len(longest_sentence22_tokenized)

num_words22
# Out:
# 54

# %%
longest_sentence22
# Out:
# 'Writers such as Petrarch (1304-1374) and Giovanni Boccaccio (1313-1375) looked back to ancient Greece and Rome and sought to revive the languages, values and intellectual traditions of those cultures after the long period of stagnation that had followed the fall of the Roman Empire in the sixth century.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence22)
print("\nNumber of Words:", num_words22)
# Out:
# Longest Sentence:
# Writers such as Petrarch (1304-1374) and Giovanni Boccaccio (1313-1375) looked back to ancient Greece and Rome and sought to revive the languages, values and intellectual traditions of those cultures after the long period of stagnation that had followed the fall of the Roman Empire in the sixth century.
#
# Number of Words: 54

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence22)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence22_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# writer such as petrarch ( 1304-1374 ) and giovanni boccaccio ( 1313-1375 ) look back to ancient greec and rome and sought to reviv the languag , valu and intellectu tradit of those cultur after the long period of stagnat that had follow the fall of the roman empir in the sixth centuri .

# %%
# change the path to where your data is
corpus32 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/article3.txt"

# %%
corpus6File = open(corpus32).read()

# %%
from nltk.tokenize import word_tokenize
corpus32Tokens=nltk.word_tokenize(corpus6File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus6File
# Out:
# 'The first US COVID-19 death might have occurred in California on 6 February — three weeks before the first reported death, in Washington state.\nAfter autopsies, three people who died in Santa Clara County between 6 February and 6 March have been confirmed as having died of COVID-19, according to a statement released by the county’s department of public health on 21 April. The updated statistics include two people who died at home and a third whose location of death was not specified. Previously, the first COVID-19 death in the county was thought to have occurred on 9 March.\nThe revised cause of death shows that the deadly disease had footholds in the United States earlier than previously thought. Similar reports have surfaced elsewhere in recent weeks. In late March, a non-peer-reviewed epidemiology study of the Lombardy region in northern Italy found that the virus might have been circulating there for more than a month before it was detected.\n22 April 16:45 BST — Climate scient
# ...

# %%
# you can find the length of this blob
len(corpus32Tokens)
# Out:
# 6599

# %%
corpus32Tokens
# Out:
# ['The',
#  'first',
#  'US',
#  'COVID-19',
#  'death',
#  'might',
#  'have',
#  'occurred',
#  'in',
#  'California',
#  'on',
#  '6',
#  'February',
#  '—',
#  'three',
#  'weeks',
#  'before',
#  'the',
#  'first',
#  'reported',
#  'death',
#  ',',
#  'in',
#  'Washington',
#  'state',
#  '.',
#  'After',
#  'autopsies',
#  ',',
#  'three',
#  'people',
#  'who',
#  'died',
#  'in',
#  'Santa',
#  'Clara',
#  'County',
#  'between',
#  '6',
#  'February',
#  'and',
#  '6',
#  'March',
#  'have',
#  'been',
#  'confirmed',
#  'as',
#  'having',
#  'died',
#  'of',
#  'COVID-19',
#  ',',
#  'according',
#  'to',
#  'a',
#  'statement',
#  'released',
#  'by',
#  'the',
#  'county',
#  '’',
#  's',
#  'department',
#  'of',
#  'public',
#  'health',
#  'on',
#  '21',
#  'April',
#  '.',
#  'The',
#  'updated',
#  'statistics',
#  'include',
#  'two',
#  'people',
#  'who',
#  'died',
#  'at',
#  'home',
#  'and',
#  'a',
#  'third',
#  'whose',
#  'location',
#  'of',
#  'death',
# ...

# %%
# types of words in corpus32Tokens
set(corpus32Tokens)
# Out:
# {'followed',
#  'winning',
#  'imagination',
#  'only',
#  'preprint',
#  'strengths',
#  'biomedical',
#  'James',
#  'suspected',
#  'network',
#  'Researchers',
#  'candidate',
#  'first',
#  'logistics',
#  'American',
#  'I',
#  'estimated',
#  'predictions',
#  'moment',
#  'wasn',
#  'before',
#  'ship',
#  'experimenters',
#  'one',
#  'epidemiologists',
#  'Mathematician',
#  'shows',
#  'averted',
#  'having',
#  'progress',
#  'thought',
#  'mission',
#  'who',
#  'building',
#  'forum',
#  'exported',
#  'maths',
#  'Commission',
#  'McVernon',
#  'World',
#  'distancing',
#  'such',
#  'handling',
#  'And',
#  'been',
#  'designing',
#  'miniature',
#  'Game',
#  'compared',
#  'weeks',
#  'safely',
#  'controversial',
#  't',
#  'control',
#  'offering',
#  'local',
#  'chair',
#  'own',
#  'bioethicist',
#  'now',
#  'Halifax',
#  'contact',
#  'Di',
#  'months',
#  'Physics',
#  'behind',
#  '100,000',
#  '1,033',
#  'do',
#  'losing',
#  'Tuesday',
#  'Typical',
# ...

# %%
len(set(corpus32Tokens))
# Out:
# 1376

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus32Tokens))
# Out:
# ['$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '.One',
#  '//www.nature.com/articles/d41586-020-00154-w',
#  '02:00',
#  '07:00',
#  '1',
#  '1,033',
#  '1,123',
#  '1,300',
#  '1,500',
#  '1.4',
#  '1.5',
#  '1.9',
#  '100',
#  '100,000',
#  '11',
#  '11-million-person',
#  '12',
#  '128,000',
#  '14',
#  '14-day',
#  '15',
#  '15:00',
#  '15:30',
#  '16:00',
#  '16:45',
#  '17',
#  '17:00',
#  '17:05',
#  '18',
#  '1958',
#  '1970',
#  '1970s',
#  '1983',
#  '1987',
#  '1991',
#  '1Day',
#  '2,200',
#  '2.8-billion',
#  '20',
#  '20,000',
#  '2000s',
#  '2007',
#  '2015',
#  '2020',
#  '2021',
#  '20:40',
#  '21',
#  '21:00',
#  '22',
#  '22:00',
#  '22:30',
#  '23',
#  '24',
#  '24,000',
#  '26,000',
#  '29',
#  '2D',
#  '3,869',
#  '30',
#  '300,000',
#  '304,000',
#  '32',
#  '35',
#  '35,000',
#  '3D-printed',
#  '4,600',
#  '4.9',
#  '5',
#  '5,000',
#  '50',
#  '500',
#  '579',
#  '59',
#  '6',
#  '6,000',
#  '600,000',
#  '69',
#  '7',
#  '7000',
#  '8',
#  '80,000',
# ...

# %%
# sorted list of all types in corpus32Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus32Tokens))
# Out:
# ['$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '.one',
#  '//www.nature.com/articles/d41586-020-00154-w',
#  '02:00',
#  '07:00',
#  '1',
#  '1,033',
#  '1,123',
#  '1,300',
#  '1,500',
#  '1.4',
#  '1.5',
#  '1.9',
#  '100',
#  '100,000',
#  '11',
#  '11-million-person',
#  '12',
#  '128,000',
#  '14',
#  '14-day',
#  '15',
#  '15:00',
#  '15:30',
#  '16:00',
#  '16:45',
#  '17',
#  '17:00',
#  '17:05',
#  '18',
#  '1958',
#  '1970',
#  '1970s',
#  '1983',
#  '1987',
#  '1991',
#  '1day',
#  '2,200',
#  '2.8-billion',
#  '20',
#  '20,000',
#  '2000s',
#  '2007',
#  '2015',
#  '2020',
#  '2021',
#  '20:40',
#  '21',
#  '21:00',
#  '22',
#  '22:00',
#  '22:30',
#  '23',
#  '24',
#  '24,000',
#  '26,000',
#  '29',
#  '2d',
#  '3,869',
#  '30',
#  '300,000',
#  '304,000',
#  '32',
#  '35',
#  '35,000',
#  '3d-printed',
#  '4,600',
#  '4.9',
#  '5',
#  '5,000',
#  '50',
#  '500',
#  '579',
#  '59',
#  '6',
#  '6,000',
#  '600,000',
#  '69',
#  '7',
#  '7000',
#  '8',
#  '80,000',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus32Tokens)
# Out:
# 0.2085164418851341

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus32Freq = nltk.FreqDist(corpus32Tokens)

# %%
fdist32 = FreqDist(corpus32Tokens)

# %%
fdist32.most_common(10)
# Out:
# [('the', 331),
#  (',', 311),
#  ('.', 224),
#  ('of', 178),
#  ('to', 159),
#  ('and', 141),
#  ('in', 140),
#  ('a', 123),
#  ('on', 74),
#  ('The', 68)]

# %%
fdist32.hapaxes()
# Out:
# ['https',
#  '//www.nature.com/articles/d41586-020-00154-w',
#  'NEWS',
#  '2020',
#  'months',
#  'happened',
#  '17:05',
#  '02:00',
#  'suspends',
#  '17:00',
#  'Mathematician',
#  'Conway.Credit',
#  'University/Office',
#  'Communications/Denise',
#  'Applewhite',
#  '.One',
#  'main',
#  'projects',
#  'High',
#  'Energy',
#  'Physics',
#  'Community',
#  'Ventilator',
#  'HEV',
#  'Because',
#  'Large',
#  'Hadron',
#  'Collider',
#  'extensive',
#  'experience',
#  'managing',
#  'gas',
#  'flows',
#  'systems',
#  'well-positioned',
#  'posted',
#  'arXiv',
#  'soliciting',
#  'feedback',
#  'prototype',
#  'professionals',
#  'ready',
#  'production',
#  'maximum',
#  '3D-printed',
#  'masks',
#  'face',
#  'shields',
#  'emergency-response',
#  'departments',
#  'centre',
#  'offering',
#  'high-performance',
#  'computing',
#  'epidemiologists',
#  'virologists',
#  'searching',
#  'necessities',
#  'elderly',
#  'otherwise',
#  'at-risk',
#  'Going',
#  'continue',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences32 = sent_tokenize(corpus6File)

# %%
sentences32
# Out:
# ['The first US COVID-19 death might have occurred in California on 6 February — three weeks before the first reported death, in Washington state.',
#  'After autopsies, three people who died in Santa Clara County between 6 February and 6 March have been confirmed as having died of COVID-19, according to a statement released by the county’s department of public health on 21 April.',
#  'The updated statistics include two people who died at home and a third whose location of death was not specified.',
#  'Previously, the first COVID-19 death in the county was thought to have occurred on 9 March.',
#  'The revised cause of death shows that the deadly disease had footholds in the United States earlier than previously thought.',
#  'Similar reports have surfaced elsewhere in recent weeks.',
# ...

# %%
longest_sentence32 = max(sentences32)
longest_sentence32_tokenized = nltk.word_tokenize(longest_sentence32)
num_words32 = len(longest_sentence32_tokenized)

num_words32
# Out:
# 41

# %%
longest_sentence32
# Out:
# '“We’re really in a very lucky position where we can think about the next steps and the very challenging questions ahead, but from a position of relative calm as opposed to crisis,” said McCaw.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence32)
print("\nNumber of Words:", num_words32)
# Out:
# Longest Sentence:
# “We’re really in a very lucky position where we can think about the next steps and the very challenging questions ahead, but from a position of relative calm as opposed to crisis,” said McCaw.
#
# Number of Words: 41

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence32)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence32_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# “ we ’ re realli in a veri lucki posit where we can think about the next step and the veri challeng question ahead , but from a posit of rel calm as oppos to crisi , ” said mccaw .

# %%
# change the path to where your data is
corpus33 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/science1.txt"

# %%
corpus7File = open(corpus33).read()

# %%
from nltk.tokenize import word_tokenize
corpus33Tokens=nltk.word_tokenize(corpus7File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus7File
# Out:
# 'https://www.nytimes.com/2020/02/20/education/learning/education-technology.html\nThis article is part of our latest Learning special report. We’re focusing on Generation Z, which is facing challenges from changing curriculums and new technology to financial aid gaps and homelessness.\nMANCHESTER, N.H. — Cruising to class in her driverless car, a student crams from notes projected on the inside of the windshield while she gestures with her hands to shape a 3-D holographic model of her architecture project.\nIt looks like science fiction, an impression reinforced by the fact that it is being demonstrated in virtual reality in an ultramodern space with overstuffed pillows for seats. But this scenario is based on technology already in development.\nThe setting is the Sandbox ColLABorative, the innovation arm of Southern New Hampshire University, on the fifth floor of a downtown building with panoramic views of the sprawling red brick mills that date from this city’s 19th-century industr
# ...

# %%
# you can find the length of this blob
len(corpus33Tokens)
# Out:
# 1800

# %%
corpus33Tokens
# Out:
# ['https',
#  ':',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  'This',
#  'article',
#  'is',
#  'part',
#  'of',
#  'our',
#  'latest',
#  'Learning',
#  'special',
#  'report',
#  '.',
#  'We',
#  '’',
#  're',
#  'focusing',
#  'on',
#  'Generation',
#  'Z',
#  ',',
#  'which',
#  'is',
#  'facing',
#  'challenges',
#  'from',
#  'changing',
#  'curriculums',
#  'and',
#  'new',
#  'technology',
#  'to',
#  'financial',
#  'aid',
#  'gaps',
#  'and',
#  'homelessness',
#  '.',
#  'MANCHESTER',
#  ',',
#  'N.H.',
#  '—',
#  'Cruising',
#  'to',
#  'class',
#  'in',
#  'her',
#  'driverless',
#  'car',
#  ',',
#  'a',
#  'student',
#  'crams',
#  'from',
#  'notes',
#  'projected',
#  'on',
#  'the',
#  'inside',
#  'of',
#  'the',
#  'windshield',
#  'while',
#  'she',
#  'gestures',
#  'with',
#  'her',
#  'hands',
#  'to',
#  'shape',
#  'a',
#  '3-D',
#  'holographic',
#  'model',
#  'of',
#  'her',
#  'architecture',
#  'project',
#  '.',
# ...

# %%
# types of words in corpus33Tokens
set(corpus33Tokens)
# Out:
# {'$',
#  '&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  '102',
#  '15-foot',
#  '18',
#  '18-',
#  '19th-century',
#  '200',
#  '21st',
#  '24-year-olds',
#  '3-D',
#  '30',
#  '301',
#  '360-degree',
#  '425',
#  '47',
#  '525',
#  '738,428',
#  '94',
#  ':',
#  ';',
#  '?',
#  'A',
#  'A.I',
#  'A.S.U',
#  'Academic',
#  'Alliance',
#  'America',
#  'American',
#  'And',
#  'Ann',
#  'Another',
#  'Arizona',
#  'At',
#  'Barnes',
#  'Biology',
#  'Boise',
#  'Business',
#  'But',
#  'Center',
#  'Century',
#  'China',
#  'Chinese',
#  'ColLABorative',
#  'College',
#  'Credential',
#  'Cruising',
#  'DeMillo',
#  'Design',
#  'Donna',
#  'Dr.',
#  'EdPlus',
#  'Education',
#  'Engine',
#  'Engineering',
#  'Entangled',
#  'Even',
#  'Everybody',
#  'Future',
#  'Generation',
#  'Georgia',
#  'Gordon',
#  'HAIL',
#  'Hampshire',
#  'Harvesting',
#  'Hechinger',
#  'Herman',
#  'Hey',
#  'However',
#  'Hudson',
# ...

# %%
len(set(corpus33Tokens))
# Out:
# 770

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus33Tokens))
# Out:
# ['$',
#  '&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  '102',
#  '15-foot',
#  '18',
#  '18-',
#  '19th-century',
#  '200',
#  '21st',
#  '24-year-olds',
#  '3-D',
#  '30',
#  '301',
#  '360-degree',
#  '425',
#  '47',
#  '525',
#  '738,428',
#  '94',
#  ':',
#  ';',
#  '?',
#  'A',
#  'A.I',
#  'A.S.U',
#  'Academic',
#  'Alliance',
#  'America',
#  'American',
#  'And',
#  'Ann',
#  'Another',
#  'Arizona',
#  'At',
#  'Barnes',
#  'Biology',
#  'Boise',
#  'Business',
#  'But',
#  'Center',
#  'Century',
#  'China',
#  'Chinese',
#  'ColLABorative',
#  'College',
#  'Credential',
#  'Cruising',
#  'DeMillo',
#  'Design',
#  'Donna',
#  'Dr.',
#  'EdPlus',
#  'Education',
#  'Engine',
#  'Engineering',
#  'Entangled',
#  'Even',
#  'Everybody',
#  'Future',
#  'Generation',
#  'Georgia',
#  'Gordon',
#  'HAIL',
#  'Hampshire',
#  'Harvesting',
#  'Hechinger',
#  'Herman',
#  'Hey',
#  'However',
#  'Hudson',
# ...

# %%
# sorted list of all types in corpus33Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus33Tokens))
# Out:
# ['$',
#  '&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  '102',
#  '15-foot',
#  '18',
#  '18-',
#  '19th-century',
#  '200',
#  '21st',
#  '24-year-olds',
#  '3-d',
#  '30',
#  '301',
#  '360-degree',
#  '425',
#  '47',
#  '525',
#  '738,428',
#  '94',
#  ':',
#  ';',
#  '?',
#  'a',
#  'a.i',
#  'a.s.u',
#  'about',
#  'academic',
#  'access',
#  'according',
#  'accumulated',
#  'achievement',
#  'acquire',
#  'acronyms',
#  'actively',
#  'actually',
#  'added',
#  'advances',
#  'advisers',
#  'advising',
#  'against',
#  'aid',
#  'alert',
#  'all',
#  'alliance',
#  'almost',
#  'alongside',
#  'already',
#  'also',
#  'ambitious',
#  'america',
#  'american',
#  'among',
#  'an',
#  'analysis',
#  'and',
#  'ann',
#  'another',
#  'answered',
#  'answers',
#  'appears',
#  'application',
#  'apprenticeships',
#  'archaeological',
#  'architecture',
#  'are',
#  'arizona',
#  'arm',
#  'article',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus33Tokens)
# Out:
# 0.42777777777777776

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus33Freq = nltk.FreqDist(corpus33Tokens)

# %%
fdist33 = FreqDist(corpus33Tokens)

# %%
fdist33.most_common(10)
# Out:
# [(',', 91),
#  ('.', 69),
#  ('the', 54),
#  ('to', 48),
#  ('of', 43),
#  ('and', 36),
#  ('in', 35),
#  ('a', 34),
#  ('with', 22),
#  ('for', 22)]

# %%
fdist33.hapaxes()
# Out:
# ['https',
#  '//www.nytimes.com/2020/02/20/education/learning/education-technology.html',
#  'article',
#  'part',
#  'our',
#  'latest',
#  'Learning',
#  'special',
#  'report',
#  'focusing',
#  'facing',
#  'changing',
#  'curriculums',
#  'aid',
#  'gaps',
#  'homelessness',
#  'MANCHESTER',
#  'N.H.',
#  'Cruising',
#  'class',
#  'driverless',
#  'car',
#  'crams',
#  'notes',
#  'windshield',
#  'while',
#  'hands',
#  '3-D',
#  'holographic',
#  'architecture',
#  'looks',
#  'science',
#  'fiction',
#  'impression',
#  'reinforced',
#  'demonstrated',
#  'ultramodern',
#  'space',
#  'overstuffed',
#  'pillows',
#  'seats',
#  'scenario',
#  'development',
#  'setting',
#  'Sandbox',
#  'ColLABorative',
#  'arm',
#  'fifth',
#  'floor',
#  'downtown',
#  'building',
#  'panoramic',
#  'views',
#  'sprawling',
#  'red',
#  'brick',
#  'date',
#  'city',
#  '19th-century',
#  'industrial',
#  'heyday',
#  'small',
#  'growing',
#  'number',
#  'experts',
#  'using',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences33 = sent_tokenize(corpus7File)

# %%
sentences33
# Out:
# ['https://www.nytimes.com/2020/02/20/education/learning/education-technology.html\nThis article is part of our latest Learning special report.',
#  'We’re focusing on Generation Z, which is facing challenges from changing curriculums and new technology to financial aid gaps and homelessness.',
#  'MANCHESTER, N.H. — Cruising to class in her driverless car, a student crams from notes projected on the inside of the windshield while she gestures with her hands to shape a 3-D holographic model of her architecture project.',
#  'It looks like science fiction, an impression reinforced by the fact that it is being demonstrated in virtual reality in an ultramodern space with overstuffed pillows for seats.',
#  'But this scenario is based on technology already in development.',
# ...

# %%
longest_sentence33 = max(sentences33)
longest_sentence33_tokenized = nltk.word_tokenize(longest_sentence33)
num_words33 = len(longest_sentence33_tokenized)

num_words33
# Out:
# 32

# %%
longest_sentence33
# Out:
# '“Why not use that to actually engage them?”\nSlightly less sophisticated simulations are being used in schools of education, where trainee teachers practice coping with simulated schoolchildren.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence33)
print("\nNumber of Words:", num_words33)
# Out:
# Longest Sentence:
# “Why not use that to actually engage them?”
# Slightly less sophisticated simulations are being used in schools of education, where trainee teachers practice coping with simulated schoolchildren.
#
# Number of Words: 32

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence33)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence33_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# “ whi not use that to actual engag them ? ” slightli less sophist simul are be use in school of educ , where traine teacher practic cope with simul schoolchildren .

# %%
# change the path to where your data is
corpus34 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/science2.txt"

# %%
corpus8File = open(corpus34).read()

# %%
from nltk.tokenize import word_tokenize
corpus34Tokens=nltk.word_tokenize(corpus8File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus8File
# Out:
# 'https://knowledge.wharton.upenn.edu/article/impact-of-social-media/ \nIn little more than a decade, the impact of social media has gone from being an entertaining extra to a fully integrated part of nearly every aspect of daily life for many.\nRecently in the realm of commerce, Facebook faced skepticism in its testimony to the Senate Banking Committee on Libra, its proposed cryptocurrency and alternative financial system. In politics, heartthrob Justin Bieber tweeted the President of the United States, imploring him to “let those kids out of cages.” In law enforcement, the Philadelphia police department moved to terminate more than a dozen police officers after their racist comments on social media were revealed.\nAnd in the ultimate meshing of the digital and physical worlds, Elon Musk raised the specter of essentially removing the space between social and media through the invention — at some future time — of a brain implant that connects human tissue to computer chips.\nAll this,
# ...

# %%
# you can find the length of this blob
len(corpus34Tokens)
# Out:
# 3212

# %%
corpus34Tokens
# Out:
# ['https',
#  ':',
#  '//knowledge.wharton.upenn.edu/article/impact-of-social-media/',
#  'In',
#  'little',
#  'more',
#  'than',
#  'a',
#  'decade',
#  ',',
#  'the',
#  'impact',
#  'of',
#  'social',
#  'media',
#  'has',
#  'gone',
#  'from',
#  'being',
#  'an',
#  'entertaining',
#  'extra',
#  'to',
#  'a',
#  'fully',
#  'integrated',
#  'part',
#  'of',
#  'nearly',
#  'every',
#  'aspect',
#  'of',
#  'daily',
#  'life',
#  'for',
#  'many',
#  '.',
#  'Recently',
#  'in',
#  'the',
#  'realm',
#  'of',
#  'commerce',
#  ',',
#  'Facebook',
#  'faced',
#  'skepticism',
#  'in',
#  'its',
#  'testimony',
#  'to',
#  'the',
#  'Senate',
#  'Banking',
#  'Committee',
#  'on',
#  'Libra',
#  ',',
#  'its',
#  'proposed',
#  'cryptocurrency',
#  'and',
#  'alternative',
#  'financial',
#  'system',
#  '.',
#  'In',
#  'politics',
#  ',',
#  'heartthrob',
#  'Justin',
#  'Bieber',
#  'tweeted',
#  'the',
#  'President',
#  'of',
#  'the',
#  'United',
#  'States',
#  ',',
# ...

# %%
# types of words in corpus34Tokens
set(corpus34Tokens)
# Out:
# {'preferences',
#  'between',
#  'stricter',
#  'traditional',
#  'smaller',
#  'forums',
#  'only',
#  '‘',
#  'James',
#  'checking',
#  'Researchers',
#  'removing',
#  'chapter',
#  'plenty',
#  'first',
#  'I',
#  'hundreds',
#  ';',
#  'collection',
#  '.',
#  'Overwatch',
#  'begun',
#  'All',
#  'interesting',
#  'departure',
#  'proposed',
#  'one',
#  'valuable',
#  'ending',
#  'according',
#  'power',
#  'business',
#  'tweeted',
#  'manipulation',
#  'customer-to-customer',
#  'desirable.',
#  'today',
#  'Things',
#  'an',
#  'internationally',
#  'laws',
#  'having',
#  'Your',
#  'set',
#  'three',
#  'world',
#  'some',
#  'He',
#  'even',
#  'elections',
#  'way',
#  'ultimate',
#  'unchanged',
#  'analog',
#  'writes',
#  'University',
#  'citizens',
#  'remain',
#  'On',
#  'emulate',
#  'President',
#  'show.',
#  'Giving',
#  'looking',
#  'enormously.',
#  'huge',
#  'who',
#  'lots',
#  'promising',
#  'enable',
#  'Yes',
#  'very',
#  'true',
#  'services',
# ...

# %%
len(set(corpus34Tokens))
# Out:
# 1094

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus34Tokens))
# Out:
# ['$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//knowledge.wharton.upenn.edu/article/impact-of-social-media/',
#  '1.1',
#  '10',
#  '11',
#  '143',
#  '15',
#  '1970s',
#  '2.38',
#  '2006',
#  '2007',
#  '2018',
#  '2019',
#  '2020',
#  '26',
#  '30-person',
#  '42',
#  '50',
#  '7.3',
#  '750',
#  ':',
#  ';',
#  '?',
#  'A',
#  'Absent',
#  'Accounts',
#  'All',
#  'Along',
#  'Americans',
#  'Among',
#  'Analytica',
#  'And',
#  'Arguments',
#  'As',
#  'At',
#  'Auto',
#  'Banking',
#  'Before',
#  'Berger',
#  'Bieber',
#  'Big',
#  'Brown',
#  'Cambridge',
#  'Can',
#  'Catch',
#  'Center',
#  'China',
#  'Clinical',
#  'Comcast',
#  'Committee',
#  'Contagious',
#  'D-Ohio',
#  'Damaging',
#  'Data',
#  'Decreases',
#  'Deibert',
#  'Deleting',
#  'Democracy',
#  'Department',
#  'Depression.',
#  'Does',
#  'E-sports',
#  'E.',
#  'EU',
#  'Elon',
#  'European',
#  'Even',
#  'FOMO',
#  'Facebook',
#  'Fader',
#  'For',
#  'Foundation',
#  'Friendster',
#  'Fusion',
# ...

# %%
# sorted list of all types in corpus34Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus34Tokens))
# Out:
# ['$',
#  '%',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//knowledge.wharton.upenn.edu/article/impact-of-social-media/',
#  '1.1',
#  '10',
#  '11',
#  '143',
#  '15',
#  '1970s',
#  '2.38',
#  '2006',
#  '2007',
#  '2018',
#  '2019',
#  '2020',
#  '26',
#  '30-person',
#  '42',
#  '50',
#  '7.3',
#  '750',
#  ':',
#  ';',
#  '?',
#  '[',
#  ']',
#  'a',
#  'able',
#  'about',
#  'absent',
#  'absolutely',
#  'academics',
#  'access',
#  'according',
#  'account',
#  'accountability',
#  'accounts',
#  'achieving',
#  'across',
#  'act',
#  'active',
#  'activities',
#  'adaptive',
#  'addiction',
#  'addictive',
#  'addictive.',
#  'additional',
#  'adds',
#  'adjunct',
#  'adjusts',
#  'adopted',
#  'adopting',
#  'advertising',
#  'after',
#  'again',
#  'agencies',
#  'ago',
#  'agree',
#  'aim',
#  'airplane',
#  'algorithms',
#  'all',
#  'allowed',
#  'along',
#  'already',
#  'also',
#  'alternative',
#  'always',
#  'americans',
#  'among',
#  'an',
#  'analog',
#  'analytica',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus34Tokens)
# Out:
# 0.34059775840597756

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus34Freq = nltk.FreqDist(corpus34Tokens)

# %%
fdist34 = FreqDist(corpus34Tokens)

# %%
fdist34.most_common(10)
# Out:
# [(',', 180),
#  ('the', 113),
#  ('of', 92),
#  ('and', 90),
#  ('.', 87),
#  ('to', 85),
#  ('a', 54),
#  ('“', 48),
#  ('that', 46),
#  ('”', 45)]

# %%
fdist34.hapaxes()
# Out:
# ['https',
#  '//knowledge.wharton.upenn.edu/article/impact-of-social-media/',
#  'little',
#  'decade',
#  'entertaining',
#  'extra',
#  'fully',
#  'integrated',
#  'daily',
#  'Recently',
#  'realm',
#  'commerce',
#  'faced',
#  'skepticism',
#  'testimony',
#  'Libra',
#  'proposed',
#  'cryptocurrency',
#  'alternative',
#  'financial',
#  'system',
#  'heartthrob',
#  'Justin',
#  'Bieber',
#  'tweeted',
#  'President',
#  'United',
#  'States',
#  'imploring',
#  'him',
#  'let',
#  'kids',
#  'cages.',
#  'law',
#  'department',
#  'terminate',
#  'officers',
#  'after',
#  'racist',
#  'comments',
#  'revealed',
#  'ultimate',
#  'meshing',
#  'Elon',
#  'Musk',
#  'raised',
#  'specter',
#  'essentially',
#  'removing',
#  'space',
#  'invention',
#  'brain',
#  'implant',
#  'connects',
#  'tissue',
#  'computer',
#  'chips',
#  'span',
#  'week',
#  'As',
#  'insinuated',
#  'workplace',
#  'elsewhere',
#  'lightning',
#  'speed',
#  'tricky',
#  'predict',
#  'morph',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences34 = sent_tokenize(corpus8File)

# %%
sentences34
# Out:
# ['https://knowledge.wharton.upenn.edu/article/impact-of-social-media/ \nIn little more than a decade, the impact of social media has gone from being an entertaining extra to a fully integrated part of nearly every aspect of daily life for many.',
#  'Recently in the realm of commerce, Facebook faced skepticism in its testimony to the Senate Banking Committee on Libra, its proposed cryptocurrency and alternative financial system.',
#  'In politics, heartthrob Justin Bieber tweeted the President of the United States, imploring him to “let those kids out of cages.” In law enforcement, the Philadelphia police department moved to terminate more than a dozen police officers after their racist comments on social media were revealed.',
# ...

# %%
longest_sentence34 = max(sentences34)
longest_sentence34_tokenized = nltk.word_tokenize(longest_sentence34)
num_words34 = len(longest_sentence34_tokenized)

num_words34
# Out:
# 11

# %%
longest_sentence34
# Out:
# '“Yes, surely it does,” says Yildirim.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence34)
print("\nNumber of Words:", num_words34)
# Out:
# Longest Sentence:
# “Yes, surely it does,” says Yildirim.
#
# Number of Words: 11

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence34)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence34_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# “ ye , sure it doe , ” say yildirim .

# %%
# change the path to where your data is
corpus35 = "/Users/shubhkarman/Desktop/SDA50/SDA250/SDA250ASSIGNMENT1/data/science3.txt"

# %%
corpus9File = open(corpus35).read()

# %%
from nltk.tokenize import word_tokenize
corpus35Tokens=nltk.word_tokenize(corpus9File)

# %%
# you can print it, to see that you have a blob of text from the file
corpus9File
# Out:
# 'https://www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/?utm_source=google-rsa&utm_medium=sem&utm_campaign=457305&utm_content=embracing_ai&gclid=Cj0KCQiAmNeqBhD4ARIsADsYfTdBlGSJ_S_roZZ9spnMSCP8ltS2trJ5KLEmTZsPdz1Aa0lDRUEIag0aAh57EALw_wcB\nust as organizations and industries of all shapes and sizes were transformed by the rise of the internet, so too will their future be shaped by artificial intelligence (AI).\n“The risk of not using AI is getting left behind,” says Jeff Healey, vice-president of analytics and AI product marketing at OpenText.\nOpenText is an organization with 30 years of experience helping the world’s leading companies digitally transform. Now, it’s embracing AI wholeheartedly and embedding this revolutionary technology into major aspects of its own solutions.\nCompanies that aren’t considering leveraging AI could find themselves at a major disadvantage, Mr. Healey says.\n“It’s not an option. IT leaders should be asking, ‘How can we 
# ...

# %%
# you can find the length of this blob
len(corpus35Tokens)
# Out:
# 1037

# %%
corpus35Tokens
# Out:
# ['https',
#  ':',
#  '//www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/',
#  '?',
#  'utm_source=google-rsa',
#  '&',
#  'utm_medium=sem',
#  '&',
#  'utm_campaign=457305',
#  '&',
#  'utm_content=embracing_ai',
#  '&',
#  'gclid=Cj0KCQiAmNeqBhD4ARIsADsYfTdBlGSJ_S_roZZ9spnMSCP8ltS2trJ5KLEmTZsPdz1Aa0lDRUEIag0aAh57EALw_wcB',
#  'ust',
#  'as',
#  'organizations',
#  'and',
#  'industries',
#  'of',
#  'all',
#  'shapes',
#  'and',
#  'sizes',
#  'were',
#  'transformed',
#  'by',
#  'the',
#  'rise',
#  'of',
#  'the',
#  'internet',
#  ',',
#  'so',
#  'too',
#  'will',
#  'their',
#  'future',
#  'be',
#  'shaped',
#  'by',
#  'artificial',
#  'intelligence',
#  '(',
#  'AI',
#  ')',
#  '.',
#  '“',
#  'The',
#  'risk',
#  'of',
#  'not',
#  'using',
#  'AI',
#  'is',
#  'getting',
#  'left',
#  'behind',
#  ',',
#  '”',
#  'says',
#  'Jeff',
#  'Healey',
#  ',',
#  'vice-president',
#  'of',
#  'analytics',
#  'and',
#  'AI',
#  'product',
# ...

# %%
# types of words in corpus35Tokens
set(corpus35Tokens)
# Out:
# {'&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/',
#  '30',
#  '34',
#  '56',
#  ':',
#  '?',
#  'AI',
#  'According',
#  'And',
#  'As',
#  'By',
#  'Companies',
#  'DevOps',
#  'Every',
#  'For',
#  'Gartner',
#  'Healey',
#  'How',
#  'I',
#  'IT',
#  'IoT',
#  'It',
#  'Jackson',
#  'Jeff',
#  'Kool-Aid',
#  'Leveraging',
#  'Many',
#  'Mr.',
#  'Ms.',
#  'Now',
#  'OpenText',
#  'Organizations',
#  'RFID',
#  'Rita',
#  'She',
#  'So',
#  'That',
#  'The',
#  'This',
#  'Unlike',
#  'Unlocking',
#  'We',
#  'What',
#  'When',
#  'a',
#  'able',
#  'about',
#  'accelerate',
#  'access',
#  'accurate',
#  'accurately',
#  'across',
#  'act',
#  'actively',
#  'activities',
#  'adaptation',
#  'adds',
#  'adopt',
#  'advantage.',
#  'advantages',
#  'afford',
#  'affordable',
#  'agile',
#  'all',
#  'already',
#  'also',
#  'amounts',
#  'an',
#  'analytics',
#  'analyze',
#  'analyzing',
#  'and',
# ...

# %%
len(set(corpus35Tokens))
# Out:
# 440

# %%
# same as above, but sorted in alphabetical order, with punctuation and numbers first
sorted(set(corpus35Tokens))
# Out:
# ['&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/',
#  '30',
#  '34',
#  '56',
#  ':',
#  '?',
#  'AI',
#  'According',
#  'And',
#  'As',
#  'By',
#  'Companies',
#  'DevOps',
#  'Every',
#  'For',
#  'Gartner',
#  'Healey',
#  'How',
#  'I',
#  'IT',
#  'IoT',
#  'It',
#  'Jackson',
#  'Jeff',
#  'Kool-Aid',
#  'Leveraging',
#  'Many',
#  'Mr.',
#  'Ms.',
#  'Now',
#  'OpenText',
#  'Organizations',
#  'RFID',
#  'Rita',
#  'She',
#  'So',
#  'That',
#  'The',
#  'This',
#  'Unlike',
#  'Unlocking',
#  'We',
#  'What',
#  'When',
#  'a',
#  'able',
#  'about',
#  'accelerate',
#  'access',
#  'accurate',
#  'accurately',
#  'across',
#  'act',
#  'actively',
#  'activities',
#  'adaptation',
#  'adds',
#  'adopt',
#  'advantage.',
#  'advantages',
#  'afford',
#  'affordable',
#  'agile',
#  'all',
#  'already',
#  'also',
#  'amounts',
#  'an',
#  'analytics',
#  'analyze',
#  'analyzing',
#  'and',
# ...

# %%
# sorted list of all types in corpus35Tokens, all in lower case. Types includes punctuation and numbers 
sorted(set(w.lower() for w in corpus35Tokens))
# Out:
# ['&',
#  '(',
#  ')',
#  ',',
#  '.',
#  '//www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/',
#  '30',
#  '34',
#  '56',
#  ':',
#  '?',
#  'a',
#  'able',
#  'about',
#  'accelerate',
#  'access',
#  'according',
#  'accurate',
#  'accurately',
#  'across',
#  'act',
#  'actively',
#  'activities',
#  'adaptation',
#  'adds',
#  'adopt',
#  'advantage.',
#  'advantages',
#  'afford',
#  'affordable',
#  'agile',
#  'ai',
#  'all',
#  'already',
#  'also',
#  'amounts',
#  'an',
#  'analytics',
#  'analyze',
#  'analyzing',
#  'and',
#  'another',
#  'any',
#  'appear',
#  'application',
#  'applications',
#  'are',
#  'aren',
#  'around',
#  'artificial',
#  'as',
#  'asking',
#  'aspects',
#  'assessing',
#  'asset',
#  'assets',
#  'at',
#  'augment',
#  'automate',
#  'automatically',
#  'automating',
#  'automation',
#  'back',
#  'be',
#  'beautiful',
#  'become',
#  'been',
#  'before',
#  'behind',
#  'being',
#  'benefits',
#  'better',
# ...

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
lexical_diversity(corpus35Tokens)
# Out:
# 0.42430086788813887

# %%
# build a dictionary of the frequency count of the words
#from nltk.tokenize import word_tokenize
corpus35Freq = nltk.FreqDist(corpus35Tokens)

# %%
fdist35 = FreqDist(corpus35Tokens)

# %%
fdist35.most_common(10)
# Out:
# [(',', 55),
#  ('.', 37),
#  ('and', 32),
#  ('AI', 29),
#  ('of', 27),
#  ('the', 26),
#  ('to', 22),
#  ('can', 19),
#  ('’', 17),
#  ('that', 15)]

# %%
fdist35.hapaxes()
# Out:
# ['https',
#  '//www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/',
#  'utm_source=google-rsa',
#  'utm_medium=sem',
#  'utm_campaign=457305',
#  'utm_content=embracing_ai',
#  'gclid=Cj0KCQiAmNeqBhD4ARIsADsYfTdBlGSJ_S_roZZ9spnMSCP8ltS2trJ5KLEmTZsPdz1Aa0lDRUEIag0aAh57EALw_wcB',
#  'ust',
#  'industries',
#  'shapes',
#  'sizes',
#  'were',
#  'transformed',
#  'rise',
#  'too',
#  'future',
#  'shaped',
#  'artificial',
#  'intelligence',
#  'left',
#  'behind',
#  'Jeff',
#  '30',
#  'years',
#  'experience',
#  'helping',
#  'world',
#  'leading',
#  'digitally',
#  'transform',
#  'Now',
#  'embracing',
#  'wholeheartedly',
#  'embedding',
#  'revolutionary',
#  'aspects',
#  'its',
#  'Companies',
#  'aren',
#  'considering',
#  'could',
#  'find',
#  'themselves',
#  'disadvantage',
#  'option',
#  'leaders',
#  'asking',
#  '‘',
#  'How',
#  'embrace',
#  'agile',
#  'look',
#  'type',
#  'automation',
#  'give',
#  'advantage.',
# ...

# %%
from nltk.corpus import gutenberg
from nltk.tokenize import sent_tokenize

# Load the Gutenberg corpus
#corpus = gutenberg.raw()

# Tokenize the sentences
sentences35 = sent_tokenize(corpus9File)

# %%
sentences35
# Out:
# ['https://www.theglobeandmail.com/business/adv/article-embracing-ai-for-a-competitive-edge/?utm_source=google-rsa&utm_medium=sem&utm_campaign=457305&utm_content=embracing_ai&gclid=Cj0KCQiAmNeqBhD4ARIsADsYfTdBlGSJ_S_roZZ9spnMSCP8ltS2trJ5KLEmTZsPdz1Aa0lDRUEIag0aAh57EALw_wcB\nust as organizations and industries of all shapes and sizes were transformed by the rise of the internet, so too will their future be shaped by artificial intelligence (AI).',
#  '“The risk of not using AI is getting left behind,” says Jeff Healey, vice-president of analytics and AI product marketing at OpenText.',
#  'OpenText is an organization with 30 years of experience helping the world’s leading companies digitally transform.',
#  'Now, it’s embracing AI wholeheartedly and embedding this revolutionary technology into major aspects of its own solutions.',
#  'Companies that aren’t considering leveraging AI could find themselves at a major disadvantage, Mr. Healey says.',
#  '“It’s not an option.',
# ...

# %%
longest_sentence35 = max(sentences35)
longest_sentence35_tokenized = nltk.word_tokenize(longest_sentence35)
num_words35 = len(longest_sentence35_tokenized)

num_words35
# Out:
# 43

# %%
longest_sentence35
# Out:
# '“We’re seeing lots of AI use cases for getting access to the information people need from the applications they’re already in, and to augment and enhance the workflows that are already there,” she says.'

# %%
# Find the longest sentence


# Print the longest sentence and the number of words
print("Longest Sentence:")
print(longest_sentence35)
print("\nNumber of Words:", num_words35)
# Out:
# Longest Sentence:
# “We’re seeing lots of AI use cases for getting access to the information people need from the applications they’re already in, and to augment and enhance the workflows that are already there,” she says.
#
# Number of Words: 43

# %%
from nltk.stem import PorterStemmer

# Initialize the Porter Stemmer
porter_stemmer = PorterStemmer()

# Tokenize the longest sentence
tokenized_longest_sentence = nltk.word_tokenize(longest_sentence35)

# Stem each word in the sentence
stemmed_sentence = [porter_stemmer.stem(word) for word in longest_sentence35_tokenized]

# Print the stemmed version of the longest sentence
print("\nStemmed Version:")
print(" ".join(stemmed_sentence))
# Out:
# Stemmed Version:
# “ we ’ re see lot of ai use case for get access to the inform peopl need from the applic they ’ re alreadi in , and to augment and enhanc the workflow that are alreadi there , ” she say .
